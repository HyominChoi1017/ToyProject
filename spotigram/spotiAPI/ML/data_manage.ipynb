# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np  

df = pd.read_pickle('./fast.pkl')
df.corr()
# Out:
#                   danceability    energy  loudness  speechiness  acousticness  \
# danceability          1.000000  0.111288  0.279554     0.240568     -0.198204
# energy                0.111288  1.000000  0.730303     0.041869     -0.661664
# loudness              0.279554  0.730303  1.000000     0.010199     -0.553081
# speechiness           0.240568  0.041869  0.010199     1.000000     -0.081023
# acousticness         -0.198204 -0.661664 -0.553081    -0.081023      1.000000
# instrumentalness     -0.255611 -0.230733 -0.503280    -0.113135      0.240819
# liveness             -0.065533  0.195084  0.105026     0.088371     -0.117684
# valence               0.401379  0.382385  0.342418     0.044025     -0.170660
# tempo                -0.048626  0.180424  0.156678     0.090070     -0.156254
#
#                   instrumentalness  liveness   valence     tempo
# danceability             -0.255611 -0.065533  0.401379 -0.048626
# ...
